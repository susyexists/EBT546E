# %%
#Import Libraries

#Numerical manipulation
import numpy as np

#Plotting routine
import matplotlib.pyplot as plt

# %% [markdown]
# $E_{\pm}(\mathbf{k})=\pm t \sqrt{1+4 \cos \left(\frac{3}{2} k_{x} a\right) \cos \left(\frac{\sqrt{3}}{2} k_{y} a\right)+4 \cos ^{2}\left(\frac{\sqrt{3}}{2} k_{y} a\right)}$

# %%
(0.33333,0.33333)
# Out:
# (0.33333, 0.33333)

# %%
#Define constant

# Hopping constant
t = 0.1 # eV

# Lattice spacing
a = 5  # Angstrom

# N number of unitcells
N = 100

# Reciprocal space length
g = 2*np.pi/a

bz = np.linspace(-g/2,g/2,N)

#Define k mesh
k_mesh = [[kx,ky]  for kx in bz for ky in bz]

#Convert list into array
k_mesh = np.array(k_mesh)

#Define kx and ky
kx, ky = k_mesh.T

# %%
def graphene(t,a,kx,ky):
    energy = t*np.sqrt(1+4*np.cos(3/2*kx*a)*np.cos(np.sqrt(3)/2*ky*a)+4*np.cos(np.sqrt(3)/2*ky*a)**2)
    return energy

# %%
energy = graphene(t,a,kx,ky)

# %%
plt.scatter(kx,ky,c=energy,cmap="jet")
plt.axis("equal")
# Out:
# (-0.6911503837897545,
#  0.6911503837897545,
#  -0.6911503837897545,
#  0.6911503837897545)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = y = np.linspace(-g/2,g/2, N)
X, Y = np.meshgrid(x, y)
zs = np.array(energy(t=t,a=a,kx=np.ravel(X), ky=np.ravel(Y)))
Za = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6fe1c26779c9> in <module>
#       1 x = y = np.linspace(-g/2,g/2, N)
#       2 X, Y = np.meshgrid(x, y)
# ----> 3 zs = np.array(energy(t=t,a=a,kx=np.ravel(X), ky=np.ravel(Y)))
#       4 Za = zs.reshape(X.shape)
#       5
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-abf60099bf8e> in <module>
#       3
#       4
# ----> 5 ax.plot_surface(X, Y, Z)
#       6
#       7 ax.set_xlabel('X Label')
#
# NameError: name 'Z' is not defined

# %%
from mpl_toolkits.mplot3d import Axes3D  

def fun(kx, ky,t=t,a=a):
    energy = t*np.sqrt(1+4*np.cos(3/2*kx*a)*np.cos(np.sqrt(3)/2*ky*a)+4*np.cos(np.sqrt(3)/2*ky*a)**2)
    return energy


x = y = np.linspace(-g/3, g/3, N)
X, Y = np.meshgrid(x, y)
zs = np.array(fun(np.ravel(X), np.ravel(Y)))
Z = zs.reshape(X.shape)

# %%
# %matplotlib widget

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, -Z)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(projection='3d')
ax.scatter(kx, ky, energy)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
energy = graphene(t,a,kx,-0.3333)

# %%
plt.plot(kx,energy)
plt.plot(kx,-energy)
plt.show()
