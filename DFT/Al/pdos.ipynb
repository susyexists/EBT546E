# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tot = np.loadtxt("pdos.dat.pdos_tot")

# %%
p = np.loadtxt('pdos.dat.pdos_atm#1(Al)_wfc#2(p)')

# %%
s = np.loadtxt('pdos.dat.pdos_atm#1(Al)_wfc#1(s)')

# %%
plt.plot(s.T[0],s.T[1],label="S")
plt.plot(p.T[0],p.T[1],label="P")
plt.plot(tot.T[0],tot.T[1],label="Total")
plt.legend()
# plt.xlim(-2,2)
plt.show()
